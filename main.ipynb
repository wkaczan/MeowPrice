# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
print('Hello Cat Lover')
# Out:
# Hello Cat Lover

# %%
url = 'https://www.zooplus.pl/shop/koty/karma_dla_kota_mokra/wild_freedom_nass/puszki/661256?zootopia_rec=true&cn=initial&si=8&pn=web_pdp&pr=container_1&strategy=51920183&rk=1-2&slot=1&pi=661256&rri=4eb72503-1ac2-4bd3-81c8-192169f5647d'

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="pl-pl"><head><meta charSet="utf-8"/><title>Wild Freedom Adult, 24 x 400 g tanio w zooplus</title><meta property="og:title" content="Wild Freedom Adult, 24 x 400 g tanio w zooplus"/><link rel="canonical" href="https://www.zooplus.pl/shop/koty/karma_dla_kota_mokra/wild_freedom_nass/puszki/661256"/><link rel="SHORTCUT ICON" href="https://shop-public-cdn.mediazs.com/theme/zooplus/zooplus.pl/image/icons/favicon.ico"/><link rel="stylesheet" href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/shop-styleguide-compat.css"/><link rel="stylesheet" href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-base.min.css"/><link rel="stylesheet" href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-components.min.css"/><link rel="stylesheet" href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-grid.min.css"/><script src="https://vam-cdn-prod.mediazs.com/js/shop/events-bus.js" defer=""></scrip
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pl-pl">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wild Freedom Adult, 24 x 400 g tanio w zooplus
#   </title>
#   <meta content="Wild Freedom Adult, 24 x 400 g tanio w zooplus" property="og:title"/>
#   <link href="https://www.zooplus.pl/shop/koty/karma_dla_kota_mokra/wild_freedom_nass/puszki/661256" rel="canonical"/>
#   <link href="https://shop-public-cdn.mediazs.com/theme/zooplus/zooplus.pl/image/icons/favicon.ico" rel="SHORTCUT ICON"/>
#   <link href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/shop-styleguide-compat.css" rel="stylesheet"/>
#   <link href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-base.min.css" rel="stylesheet"/>
#   <link href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-components.min.css" rel="stylesheet"/>
#   <link href="https://d3f959kun0takv.cloudfront.net/ui-components/5.1.1/css/library-grid.min.css" rel="stylesheet"/>
# ...

# %%
list_all_p = soup.find_all('span')
print(f'Znalazłem {len(list_all_p)} linków')
list_all_p[11].get_text()
# Out:
# Znalazłem 106 linków
# 'Wczytaj zdjęcie produktu'

# %%
list_all_p
# Out:
# [<span data-zta="backlink-text">powrót do listy produktów</span>,
#  <span class="imageSwiper_imageSwiperPreviousThumbnailsButton__FBSBA imageSwiper_imageSwiperAbstractButton__3cBDa swiper-button-prev disabled"><svg fill="currentColor" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M14.234 6.22a.75.75 0 0 1 1.133.976l-.073.084-4.626 4.625 4.626 4.627a.75.75 0 0 1 .073.977l-.073.084a.75.75 0 0 1-.976.072l-.084-.072L9.32 12.68a1.093 1.093 0 0 1-.086-1.45l.085-.096 4.914-4.914Z" fill-rule="evenodd"></path></svg></span>,
# ...

# %%
price = soup.find_all("span", {"class": "z-price__amount"})

# %%
price[0]
# Out:
# <span class="z-price__amount">209,80 zł</span>

# %%
cena = price[0].get_text()

# %%
cena
# Out:
# '209,80\xa0zł'

# %%
cena = cena.replace('\xa0',' ')
cena = cena.replace(',','.')

# %%
cena = cena.split(' ')

# %%
cena
# Out:
# ['209.80', 'zł']

# %%
cena[0]
# Out:
# '209.80'

# %%
cena = cena[0]

# %%
cena
# Out:
# '209.80'

# %%
cena = float(cena)

# %%
cena
# Out:
# 209.8
